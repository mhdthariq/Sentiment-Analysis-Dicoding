# %% [markdown]
# # 1. Import Library

# %%
from google_play_scraper import reviews_all, Sort
import pandas as pd
import csv

# %% [markdown]
# # 2. Scraping Dataset

# %%
# Mengambil semua ulasan dari aplikasi dengan ID 'com.whatsapp' di Google Play Store.
# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview = reviews_all(
    'com.whatsapp',             # ID aplikasi
    lang='id',                  # Bahasa ulasan (default: 'en')
    country='id',               # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT,    # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=20000                 # Jumlah maksimum ulasan yang ingin diambil
)

# %% [markdown]
# # 3. Simpan Dataset

# %%
with open('ulasan_aplikasi_whatsapp.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file, quoting=csv.QUOTE_ALL)  # <-- tambahkan quoting
    writer.writerow(['Review']) # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']]) # Menulis setiap ulasan ke baris baru

# %% [markdown]
# # 4. Melihat Dataset

# %%
# Membuat DataFrame
app_reviews_df = pd.DataFrame(scrapreview)

# Menampilkan informasi dataset
display(app_reviews_df.head())

# Menyimpan ke CSV
app_reviews_df.to_csv('ulasan_aplikasi_whatsapp.csv', index=False)
# Out:
#                                reviewId         userName  \
# 0  70392ee0-2287-4f65-bb5c-bffbe1cdff9c  Pengguna Google
# 1  cb19ce22-44e6-4616-8a43-634e3560284f  Pengguna Google
# 2  be9766d6-f204-4edd-a174-d0790c6ba222  Pengguna Google
# 3  570166de-3a26-4f0d-9874-9057fda88ab7  Pengguna Google
# 4  1068a744-870e-42f0-ac2a-fd6a9f2ecd02  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  untuk sampai detik ini wa masih jadi yg paling...      5            579
# 1  aplikasi nya bagus, mudah berkomunikasi dengan...      4           1228
# 2  sudah bagus apknya tpi kenapa wa saya bug si? ...      5            599
# 3  Kontak saya semua hilang tiba tiba,padahal say...      2             31
# 4  kenapa ya WA sekarang kalau mau update story w...      1            623
#
#   reviewCreatedVersion                  at replyContent repliedAt  appVersion
# 0           2.25.13.74 2025-05-01 02:25:28         None      None  2.25.13.74
# 1           2.25.11.75 2025-04-21 07:25:50         None      None  2.25.11.75
# 2           2.25.13.74 2025-05-01 10:47:29         None      None  2.25.13.74
# 3           2.25.13.74 2025-05-01 08:14:56         None      None  2.25.13.74
# 4           2.25.13.74 2025-05-01 08:14:49         None      None  2.25.13.74

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153000 entries, 0 to 152999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              153000 non-null  object
#  1   userName              153000 non-null  object
#  2   userImage             153000 non-null  object
#  3   content               153000 non-null  object
#  4   score                 153000 non-null  int64
#  5   thumbsUpCount         153000 non-null  int64
#  6   reviewCreatedVersion  137450 non-null  object
#  7   at                    153000 non-null  datetime64[ns]
#  8   replyContent          0 non-null       object
#  9   repliedAt             0 non-null       object
#  10  appVersion            137450 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 12.8+ MB
